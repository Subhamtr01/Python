# %% [markdown]
# ## MODULE 1

# %%
import os
def current_path():
	print("Current working directory")
	print(os.getcwd())
	print()
current_path()
os.chdir(r'C:\Users\manis\Downloads') # To avoid writing file path, directory is changed
current_path()
# Out:
# Current working directory
# C:\Users\manis
#
# Current working directory
# C:\Users\manis\Downloads

# %%
#Q1 Load the Sample 2 CSV File
import pandas as pd
df1 = pd.read_csv('sample2_group07_035019_035035.csv', low_memory=False)
df1
# Out:
#        Unnamed: 0  Store        Date  Temperature  Fuel_Price    MarkDown1  \
# 0               0      6  05/02/2010    40.430000    2.572000  6983.083573
# 1               1      6  12/02/2010    40.570000    2.548000  6983.083573
# 2               2      6  19/02/2010    43.580000    2.514000  6983.083573
# 3               3      6  26/02/2010    47.100000    2.561000  6983.083573
# 4               4      6  05/03/2010    49.630000    2.625000  6983.083573
# ...           ...    ...         ...          ...         ...          ...
# 84220       84220     44  12/10/2012    61.703938    3.457291  6983.083573
# 84221       84221     44  19/10/2012    61.703938    3.457291  6983.083573
# 84222       84222     44  26/10/2012    61.703938    3.457291  6983.083573
# 84223       84223     44  05/03/2010    61.703938    3.457291  6983.083573
# 84224       84224     44  30/07/2010    61.703938    3.457291  6983.083573
#
# ...

# %%
#To find the categorical variables
df1.info()
df1.select_dtypes(include=['object']).columns.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84225 entries, 0 to 84224
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           84225 non-null  int64
#  1   Store                84225 non-null  int64
#  2   Date                 84216 non-null  object
#  3   Temperature          84225 non-null  float64
#  4   Fuel_Price           84225 non-null  float64
#  5   MarkDown1            84225 non-null  float64
#  6   MarkDown2            84225 non-null  float64
#  7   MarkDown3            84225 non-null  float64
#  8   MarkDown4            84225 non-null  float64
#  9   MarkDown5            84225 non-null  float64
#  10  CPI                  84225 non-null  float64
#  11  Unemployment         84225 non-null  float64
#  12  IsHoliday            84225 non-null  object
#  13  Type                 9 non-null      object
#  14  Size                 84225 non-null  float64
# ...

# %%
#Q2Generate a Report on Descriptive Statistics of Categorical Data in the Sample

import researchpy as rp
m=rp.summary_cat(df1['Type'])
print(m)
n=m=rp.summary_cat(df1['IsHoliday'])
print(n )
s=rp.summary_cat(df1['Date'])
print(s)
# Out:
#   Variable Outcome  Count  Percent
# 0     Type       A      4    44.44
# 1                B      4    44.44
# 2                C      1    11.11
#     Variable              Outcome  Count  Percent
# 0  IsHoliday                False  78291    92.95
# 1                            True   5925     7.03
# 2             0.07035480193787404      9     0.01
#     Variable     Outcome  Count  Percent
# 0       Date  25/11/2011    601     0.71
# 1             09/12/2011    601     0.71
# 2             23/12/2011    600     0.71
# 3             16/12/2011    598     0.71
# 4             05/10/2012    598     0.71
# ..       ...         ...    ...      ...
# 177           14/06/2013      9     0.01
# 178           21/06/2013      9     0.01
# 179           28/06/2013      9     0.01
# 180           05/07/2013      9     0.01
# 181           26/07/2013      9     0.01
#
# [182 rows x 4 columns]

# %%
#Q3 Generate a Report on Descriptive Statistics of Non-Categorical Data in the Sample 
df1.info()
df1.select_dtypes(include=['int','float']).columns.tolist() #to find non categorical data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84225 entries, 0 to 84224
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           84225 non-null  int64
#  1   Store                84225 non-null  int64
#  2   Date                 84216 non-null  object
#  3   Temperature          84225 non-null  float64
#  4   Fuel_Price           84225 non-null  float64
#  5   MarkDown1            84225 non-null  float64
#  6   MarkDown2            84225 non-null  float64
#  7   MarkDown3            84225 non-null  float64
#  8   MarkDown4            84225 non-null  float64
#  9   MarkDown5            84225 non-null  float64
#  10  CPI                  84225 non-null  float64
#  11  Unemployment         84225 non-null  float64
#  12  IsHoliday            84225 non-null  object
#  13  Type                 9 non-null      object
#  14  Size                 84225 non-null  float64
# ...

# %%
df1.describe() #16 colums are for non categorical data and 16 columns are displayed below with mean,std,etc
# Out:
#          Unnamed: 0         Store   Temperature    Fuel_Price     MarkDown1  \
# count  84225.000000  84225.000000  84225.000000  84225.000000  84225.000000
# mean   42112.000000     16.766863     61.703938      3.457291   6983.083573
# std    24313.807548     11.133184      2.499178      0.061441    927.127111
# min        0.000000      6.000000     11.440000      2.472000   -772.210000
# 25%    21056.000000     10.000000     61.703938      3.457291   6983.083573
# 50%    42112.000000     14.000000     61.703938      3.457291   6983.083573
# 75%    63168.000000     19.000000     61.703938      3.457291   6983.083573
# max    84224.000000     44.000000    101.950000      4.468000  84139.360000
#
#            MarkDown2      MarkDown3     MarkDown4     MarkDown5           CPI  \
# count   84225.000000   84225.000000  84225.000000  84225.000000  84225.000000
# mean     3773.014097    2159.768700   3371.277455   3556.889679    166.883839
# ...

# %%
#Q4 Generate a Report on Feature-wise Outliers in the Sample
# Box Plot
import seaborn as sns
import matplotlib.pyplot as plt

# setting the dimensions of the plot
fig, ax = plt.subplots(figsize=(26, 10))
sns.boxplot(df1, ax=ax)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # MODULE 2

# %%
#Generate a Comprehensive Report on the Insights Drawn from the Sample about Store Performance (and/or any other Insight)

# %%
import seaborn as sns 

g = sns.catplot(data=df1, x='Store', y='Weekly_Sales', color ='green')
g.fig.set_figwidth(15)
g.fig.set_figheight(8)

plt.title("Store Performance wrt Weekly Sales")
plt.ylabel("Weekly Sales")
plt.xlabel("Stores")

plt.show()
